# %% [markdown]
# <a href="https://colab.research.google.com/github/Cristyan14/python-pandas/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

clubes = {
    'Time': [],
    'Pontuação': []
}

# %%
i = 1
n = int(input('Digite a quantidade de clubes: '))
while i <= n:
  time = input('Nome clube: ')
  pontuacao = float(input('Pontuação: '))
  clubes['Time'].append(time)
  clubes['Pontuação'].append(pontuacao)
  i = i + 1
# Out:
# Digite a quantidade de clubes: 20
# Nome clube: Botafogo
# Pontuação: 79
# Nome clube: Flamengo
# Pontuação: 70
# Nome clube: Internacional
# Pontuação: 65
# Nome clube: Corinthians
# Pontuação: 56
# Nome clube: Vasco da Gama
# Pontuação: 50
# Nome clube: Fluminense
# Pontuação: 46
# Nome clube: Bragantino
# Pontuação: 44
# Nome clube: Atlético-GO
# Pontuação: 30
# Nome clube: Cuiabá
# Pontuação: 30
# Nome clube: Criciúma
# Pontuação: 38
# Nome clube: Athletico-PR
# Pontuação: 42
# Nome clube: Juventude
# Pontuação: 45
# Nome clube: Grêmio
# Pontuação: 45
# Nome clube: Atlético-MG
# Pontuação: 47
# Nome clube: EC Vitória
# Pontuação: 47
# Nome clube: Cruzeiro
# Pontuação: 52
# Nome clube: Bahia
# Pontuação: 53
# Nome clube: São Paulo
# Pontuação: 59
# Nome clube: Fortaleza
# Pontuação: 68
# Nome clube: Palmeiras
# Pontuação: 73

# %%
dt = pd.DataFrame(clubes);
display(dt)
# Out:
#              Time  Pontuação
# 0        Botafogo       79.0
# 1        Flamengo       70.0
# 2   Internacional       65.0
# 3     Corinthians       56.0
# 4   Vasco da Gama       50.0
# 5      Fluminense       46.0
# 6      Bragantino       44.0
# 7     Atlético-GO       30.0
# 8          Cuiabá       30.0
# 9        Criciúma       38.0
# 10   Athletico-PR       42.0
# 11      Juventude       45.0
# 12         Grêmio       45.0
# 13    Atlético-MG       47.0
# 14     EC Vitória       47.0
# 15       Cruzeiro       52.0
# 16          Bahia       53.0
# 17      São Paulo       59.0
# 18      Fortaleza       68.0
# 19      Palmeiras       73.0

# %%
ordenado = dt.sort_values('Pontuação', ascending=False)
display(ordenado)
# Out:
#              Time  Pontuação
# 0        Botafogo       79.0
# 19      Palmeiras       73.0
# 1        Flamengo       70.0
# 18      Fortaleza       68.0
# 2   Internacional       65.0
# 17      São Paulo       59.0
# 3     Corinthians       56.0
# 16          Bahia       53.0
# 15       Cruzeiro       52.0
# 4   Vasco da Gama       50.0
# 13    Atlético-MG       47.0
# 14     EC Vitória       47.0
# 5      Fluminense       46.0
# 11      Juventude       45.0
# 12         Grêmio       45.0
# 6      Bragantino       44.0
# 10   Athletico-PR       42.0
# 9        Criciúma       38.0
# 8          Cuiabá       30.0
# 7     Atlético-GO       30.0

# %%
melhores_5 = ordenado.head(5)
display(melhores_5)
# Out:
#              Time  Pontuação
# 0        Botafogo       79.0
# 19      Palmeiras       73.0
# 1        Flamengo       70.0
# 18      Fortaleza       68.0
# 2   Internacional       65.0

# %%
piores_5 = ordenado.tail(5)
display(piores_5)
# Out:
#             Time  Pontuação
# 6     Bragantino       44.0
# 10  Athletico-PR       42.0
# 9       Criciúma       38.0
# 8         Cuiabá       30.0
# 7    Atlético-GO       30.0

# %%
mais_de_40 = ordenado.loc[ordenado['Pontuação'] >= 40]
display(mais_de_40)
# Out:
#              Time  Pontuação
# 0        Botafogo       79.0
# 19      Palmeiras       73.0
# 1        Flamengo       70.0
# 18      Fortaleza       68.0
# 2   Internacional       65.0
# 17      São Paulo       59.0
# 3     Corinthians       56.0
# 16          Bahia       53.0
# 15       Cruzeiro       52.0
# 4   Vasco da Gama       50.0
# 13    Atlético-MG       47.0
# 14     EC Vitória       47.0
# 5      Fluminense       46.0
# 11      Juventude       45.0
# 12         Grêmio       45.0
# 6      Bragantino       44.0
# 10   Athletico-PR       42.0

# %%
x = 1
y = 20

for index in range(len(ordenado)):
    time = ordenado.loc[index, 'Time']
    n_vitorias = int(input(f'Quantidade de vitórias do {time}:'))
    ordenado.at[index, 'Vitórias'] = n_vitorias
display(ordenado)
# Out:
# Quantidade de vitórias do Botafogo:23
# Quantidade de vitórias do Flamengo:20
# Quantidade de vitórias do Internacional:18
# Quantidade de vitórias do Corinthians:15
# Quantidade de vitórias do Vasco da Gama:14
# Quantidade de vitórias do Fluminense:12
# Quantidade de vitórias do Bragantino:10
# Quantidade de vitórias do Atlético-GO:7
# Quantidade de vitórias do Cuiabá:6
# Quantidade de vitórias do Criciúma:9
# Quantidade de vitórias do Athletico-PR:11
# Quantidade de vitórias do Juventude:11
# Quantidade de vitórias do Grêmio:12
# Quantidade de vitórias do Atlético-MG:11
# Quantidade de vitórias do EC Vitória:13
# Quantidade de vitórias do Cruzeiro:14
# Quantidade de vitórias do Bahia:15
# Quantidade de vitórias do São Paulo:17
# Quantidade de vitórias do Fortaleza:19
# Quantidade de vitórias do Palmeiras:22
#              Time  Pontuação  Vitórias
# 0        Botafogo       79.0        23
# 19      Palmeiras       73.0        22
# 1        Flamengo       70.0        20
# 18      Fortaleza       68.0        19
# 2   Internacional       65.0        18
# 17      São Paulo       59.0        17
# 3     Corinthians       56.0        15
# 16          Bahia       53.0        15
# 15       Cruzeiro       52.0        14
# 4   Vasco da Gama       50.0        14
# 13    Atlético-MG       47.0        11
# 14     EC Vitória       47.0        13
# 5      Fluminense       46.0        12
# 11      Juventude       45.0        11
# 12         Grêmio       45.0        12
# 6      Bragantino       44.0        10
# 10   Athletico-PR       42.0        11
# 9        Criciúma       38.0         9
# 8          Cuiabá       30.0         6
# 7     Atlético-GO       30.0         7

# %%
for index in range(len(ordenado)):
    time = ordenado.loc[index, 'Time']
    n_empates = int(input(f'Quantidade de empates do {time}:'))
    ordenado.at[index, 'Empates'] = n_empates
display(ordenado)
# Out:
# Quantidade de empates do Botafogo:10
# Quantidade de empates do Flamengo:10
# Quantidade de empates do Internacional:11
# Quantidade de empates do Corinthians:11
# Quantidade de empates do Vasco da Gama:8
# Quantidade de empates do Fluminense:10
# Quantidade de empates do Bragantino:14
# Quantidade de empates do Atlético-GO:9
# Quantidade de empates do Cuiabá:12
# Quantidade de empates do Criciúma:11
# Quantidade de empates do Athletico-PR:9
# Quantidade de empates do Juventude:12
# Quantidade de empates do Grêmio:9
# Quantidade de empates do Atlético-MG:14
# Quantidade de empates do EC Vitória:8
# Quantidade de empates do Cruzeiro:10
# Quantidade de empates do Bahia:8
# Quantidade de empates do São Paulo:8
# Quantidade de empates do Fortaleza:11
# Quantidade de empates do Palmeiras:7
#              Time  Pontuação  Vitórias  Empates
# 0        Botafogo       79.0        23     10.0
# 19      Palmeiras       73.0        22      7.0
# 1        Flamengo       70.0        20     10.0
# 18      Fortaleza       68.0        19     11.0
# 2   Internacional       65.0        18     11.0
# 17      São Paulo       59.0        17      8.0
# 3     Corinthians       56.0        15     11.0
# 16          Bahia       53.0        15      8.0
# 15       Cruzeiro       52.0        14     10.0
# 4   Vasco da Gama       50.0        14      8.0
# 13    Atlético-MG       47.0        11     14.0
# 14     EC Vitória       47.0        13      8.0
# 5      Fluminense       46.0        12     10.0
# 11      Juventude       45.0        11     12.0
# 12         Grêmio       45.0        12      9.0
# 6      Bragantino       44.0        10     14.0
# 10   Athletico-PR       42.0        11      9.0
# 9        Criciúma       38.0         9     11.0
# 8          Cuiabá       30.0         6     12.0
# 7     Atlético-GO       30.0         7      9.0

# %%
for index in range(len(ordenado)):
    time = ordenado.loc[index, 'Time']
    n_derrotas = int(input(f'Quantidade de derrotas do {time}:'))
    ordenado.at[index, 'Derrotas'] = n_derrotas
display(ordenado)
# Out:
# Quantidade de derrotas do Botafogo:5
# Quantidade de derrotas do Flamengo:8
# Quantidade de derrotas do Internacional:9
# Quantidade de derrotas do Corinthians:12
# Quantidade de derrotas do Vasco da Gama:16
# Quantidade de derrotas do Fluminense:16
# Quantidade de derrotas do Bragantino:14
# Quantidade de derrotas do Atlético-GO:22
# Quantidade de derrotas do Cuiabá:20
# Quantidade de derrotas do Criciúma:18
# Quantidade de derrotas do Athletico-PR:18
# Quantidade de derrotas do Juventude:15
# Quantidade de derrotas do Grêmio:17
# Quantidade de derrotas do Atlético-MG:13
# Quantidade de derrotas do EC Vitória:17
# Quantidade de derrotas do Cruzeiro:14
# Quantidade de derrotas do Bahia:15
# Quantidade de derrotas do São Paulo:13
# Quantidade de derrotas do Fortaleza:8
# Quantidade de derrotas do Palmeiras:9
#              Time  Pontuação  Vitórias  Empates  Derrotas
# 0        Botafogo       79.0        23     10.0       5.0
# 19      Palmeiras       73.0        22      7.0       9.0
# 1        Flamengo       70.0        20     10.0       8.0
# 18      Fortaleza       68.0        19     11.0       8.0
# 2   Internacional       65.0        18     11.0       9.0
# 17      São Paulo       59.0        17      8.0      13.0
# 3     Corinthians       56.0        15     11.0      12.0
# 16          Bahia       53.0        15      8.0      15.0
# 15       Cruzeiro       52.0        14     10.0      14.0
# 4   Vasco da Gama       50.0        14      8.0      16.0
# 13    Atlético-MG       47.0        11     14.0      13.0
# 14     EC Vitória       47.0        13      8.0      17.0
# 5      Fluminense       46.0        12     10.0      16.0
# 11      Juventude       45.0        11     12.0      15.0
# 12         Grêmio       45.0        12      9.0      17.0
# 6      Bragantino       44.0        10     14.0      14.0
# 10   Athletico-PR       42.0        11      9.0      18.0
# 9        Criciúma       38.0         9     11.0      18.0
# 8          Cuiabá       30.0         6     12.0      20.0
# 7     Atlético-GO       30.0         7      9.0      22.0

# %%
for index in range(len(ordenado)):
    time = ordenado.loc[index, 'Time']
    n_gols_marcados = int(input(f'Quantidade de gols marcados do {time}:'))
    ordenado.at[index, 'GM'] = n_gols_marcados
display(ordenado)
# Out:
# Quantidade de gols marcados do Botafogo:59
# Quantidade de gols marcados do Flamengo:61
# Quantidade de gols marcados do Internacional:53
# Quantidade de gols marcados do Corinthians:54
# Quantidade de gols marcados do Vasco da Gama:43
# Quantidade de gols marcados do Fluminense:33
# Quantidade de gols marcados do Bragantino:44
# Quantidade de gols marcados do Atlético-GO:29
# Quantidade de gols marcados do Cuiabá:29
# Quantidade de gols marcados do Criciúma:42
# Quantidade de gols marcados do Athletico-PR:40
# Quantidade de gols marcados do Juventude:48
# Quantidade de gols marcados do Grêmio:44
# Quantidade de gols marcados do Atlético-MG:47
# Quantidade de gols marcados do EC Vitória:45
# Quantidade de gols marcados do Cruzeiro:43
# Quantidade de gols marcados do Bahia:49
# Quantidade de gols marcados do São Paulo:53
# Quantidade de gols marcados do Fortaleza:53
# Quantidade de gols marcados do Palmeiras:60
#              Time  Pontuação  Vitórias  Empates  Derrotas    GM
# 0        Botafogo       79.0        23     10.0       5.0  59.0
# 19      Palmeiras       73.0        22      7.0       9.0  60.0
# 1        Flamengo       70.0        20     10.0       8.0  61.0
# 18      Fortaleza       68.0        19     11.0       8.0  53.0
# 2   Internacional       65.0        18     11.0       9.0  53.0
# 17      São Paulo       59.0        17      8.0      13.0  53.0
# 3     Corinthians       56.0        15     11.0      12.0  54.0
# 16          Bahia       53.0        15      8.0      15.0  49.0
# 15       Cruzeiro       52.0        14     10.0      14.0  43.0
# 4   Vasco da Gama       50.0        14      8.0      16.0  43.0
# 13    Atlético-MG       47.0        11     14.0      13.0  47.0
# 14     EC Vitória       47.0        13      8.0      17.0  45.0
# 5      Fluminense       46.0        12     10.0      16.0  33.0
# 11      Juventude       45.0        11     12.0      15.0  48.0
# 12         Grêmio       45.0        12      9.0      17.0  44.0
# 6      Bragantino       44.0        10     14.0      14.0  44.0
# 10   Athletico-PR       42.0        11      9.0      18.0  40.0
# 9        Criciúma       38.0         9     11.0      18.0  42.0
# 8          Cuiabá       30.0         6     12.0      20.0  29.0
# 7     Atlético-GO       30.0         7      9.0      22.0  29.0

# %%
for index in range(len(ordenado)):
    time = ordenado.loc[index, 'Time']
    n_contras = int(input(f'Quantidade de gols sofridos do {time}:'))
    ordenado.at[index, 'GC'] = n_contras
display(ordenado)
# Out:
# Quantidade de gols sofridos do Botafogo:29
# Quantidade de gols sofridos do Flamengo:42
# Quantidade de gols sofridos do Internacional:36
# Quantidade de gols sofridos do Corinthians:45
# Quantidade de gols sofridos do Vasco da Gama:56
# Quantidade de gols sofridos do Fluminense:39
# Quantidade de gols sofridos do Bragantino:48
# Quantidade de gols sofridos do Atlético-GO:58
# Quantidade de gols sofridos do Cuiabá:49
# Quantidade de gols sofridos do Criciúma:61
# Quantidade de gols sofridos do Athletico-PR:46
# Quantidade de gols sofridos do Juventude:59
# Quantidade de gols sofridos do Grêmio:50
# Quantidade de gols sofridos do Atlético-MG:54
# Quantidade de gols sofridos do EC Vitória:52
# Quantidade de gols sofridos do Cruzeiro:41
# Quantidade de gols sofridos do Bahia:49
# Quantidade de gols sofridos do São Paulo:43
# Quantidade de gols sofridos do Fortaleza:39
# Quantidade de gols sofridos do Palmeiras:33
#              Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC
# 0        Botafogo       79.0        23     10.0       5.0  59.0  29.0
# 19      Palmeiras       73.0        22      7.0       9.0  60.0  33.0
# 1        Flamengo       70.0        20     10.0       8.0  61.0  42.0
# 18      Fortaleza       68.0        19     11.0       8.0  53.0  39.0
# 2   Internacional       65.0        18     11.0       9.0  53.0  36.0
# 17      São Paulo       59.0        17      8.0      13.0  53.0  43.0
# 3     Corinthians       56.0        15     11.0      12.0  54.0  45.0
# 16          Bahia       53.0        15      8.0      15.0  49.0  49.0
# 15       Cruzeiro       52.0        14     10.0      14.0  43.0  41.0
# 4   Vasco da Gama       50.0        14      8.0      16.0  43.0  56.0
# 13    Atlético-MG       47.0        11     14.0      13.0  47.0  54.0
# 14     EC Vitória       47.0        13      8.0      17.0  45.0  52.0
# 5      Fluminense       46.0        12     10.0      16.0  33.0  39.0
# 11      Juventude       45.0        11     12.0      15.0  48.0  59.0
# 12         Grêmio       45.0        12      9.0      17.0  44.0  50.0
# 6      Bragantino       44.0        10     14.0      14.0  44.0  48.0
# 10   Athletico-PR       42.0        11      9.0      18.0  40.0  46.0
# 9        Criciúma       38.0         9     11.0      18.0  42.0  61.0
# 8          Cuiabá       30.0         6     12.0      20.0  29.0  49.0
# 7     Atlético-GO       30.0         7      9.0      22.0  29.0  58.0

# %%
for index in range(len(ordenado)):
    time = ordenado.loc[index, 'Time']
    n_sg = int(input(f'Quantidade de saldo de gols do {time}:'))
    ordenado.at[index, 'SG'] = n_sg
display(ordenado)
# Out:
# Quantidade de saldo de gols do Botafogo:30
# Quantidade de saldo de gols do Flamengo:19
# Quantidade de saldo de gols do Internacional:17
# Quantidade de saldo de gols do Corinthians:9
# Quantidade de saldo de gols do Vasco da Gama:-13
# Quantidade de saldo de gols do Fluminense:-6
# Quantidade de saldo de gols do Bragantino:-4
# Quantidade de saldo de gols do Atlético-GO:-29
# Quantidade de saldo de gols do Cuiabá:-20
# Quantidade de saldo de gols do Criciúma:-19
# Quantidade de saldo de gols do Athletico-PR:-6
# Quantidade de saldo de gols do Juventude:-11
# Quantidade de saldo de gols do Grêmio:-6
# Quantidade de saldo de gols do Atlético-MG:-7
# Quantidade de saldo de gols do EC Vitória:-7
# Quantidade de saldo de gols do Cruzeiro:2
# Quantidade de saldo de gols do Bahia:0
# Quantidade de saldo de gols do São Paulo:10
# Quantidade de saldo de gols do Fortaleza:14
# Quantidade de saldo de gols do Palmeiras:27
#              Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG
# 0        Botafogo       79.0        23     10.0       5.0  59.0  29.0  30.0
# 19      Palmeiras       73.0        22      7.0       9.0  60.0  33.0  27.0
# 1        Flamengo       70.0        20     10.0       8.0  61.0  42.0  19.0
# 18      Fortaleza       68.0        19     11.0       8.0  53.0  39.0  14.0
# 2   Internacional       65.0        18     11.0       9.0  53.0  36.0  17.0
# 17      São Paulo       59.0        17      8.0      13.0  53.0  43.0  10.0
# 3     Corinthians       56.0        15     11.0      12.0  54.0  45.0   9.0
# 16          Bahia       53.0        15      8.0      15.0  49.0  49.0   0.0
# 15       Cruzeiro       52.0        14     10.0      14.0  43.0  41.0   2.0
# 4   Vasco da Gama       50.0        14      8.0      16.0  43.0  56.0 -13.0
# 13    Atlético-MG       47.0        11     14.0      13.0  47.0  54.0  -7.0
# 14     EC Vitória       47.0        13      8.0      17.0  45.0  52.0  -7.0
# 5      Fluminense       46.0        12     10.0      16.0  33.0  39.0  -6.0
# 11      Juventude       45.0        11     12.0      15.0  48.0  59.0 -11.0
# 12         Grêmio       45.0        12      9.0      17.0  44.0  50.0  -6.0
# 6      Bragantino       44.0        10     14.0      14.0  44.0  48.0  -4.0
# 10   Athletico-PR       42.0        11      9.0      18.0  40.0  46.0  -6.0
# 9        Criciúma       38.0         9     11.0      18.0  42.0  61.0 -19.0
# 8          Cuiabá       30.0         6     12.0      20.0  29.0  49.0 -20.0
# 7     Atlético-GO       30.0         7      9.0      22.0  29.0  58.0 -29.0

# %% [markdown]
# **Exercício 1:** Ordenação dos times pela maior pontuação.
#
# Ordene o DataFrame dt pela coluna "Pontuação" de forma decrescente e exiba o resultado.

# %%
ordenado_final = ordenado.sort_values(by=['Pontuação','Vitórias', 'SG', 'GM'], ascending=False)
display(ordenado_final)
# Out:
#              Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG
# 0        Botafogo       79.0        23     10.0       5.0  59.0  29.0  30.0
# 19      Palmeiras       73.0        22      7.0       9.0  60.0  33.0  27.0
# 1        Flamengo       70.0        20     10.0       8.0  61.0  42.0  19.0
# 18      Fortaleza       68.0        19     11.0       8.0  53.0  39.0  14.0
# 2   Internacional       65.0        18     11.0       9.0  53.0  36.0  17.0
# 17      São Paulo       59.0        17      8.0      13.0  53.0  43.0  10.0
# 3     Corinthians       56.0        15     11.0      12.0  54.0  45.0   9.0
# 16          Bahia       53.0        15      8.0      15.0  49.0  49.0   0.0
# 15       Cruzeiro       52.0        14     10.0      14.0  43.0  41.0   2.0
# 4   Vasco da Gama       50.0        14      8.0      16.0  43.0  56.0 -13.0
# 14     EC Vitória       47.0        13      8.0      17.0  45.0  52.0  -7.0
# 13    Atlético-MG       47.0        11     14.0      13.0  47.0  54.0  -7.0
# 5      Fluminense       46.0        12     10.0      16.0  33.0  39.0  -6.0
# 12         Grêmio       45.0        12      9.0      17.0  44.0  50.0  -6.0
# 11      Juventude       45.0        11     12.0      15.0  48.0  59.0 -11.0
# 6      Bragantino       44.0        10     14.0      14.0  44.0  48.0  -4.0
# 10   Athletico-PR       42.0        11      9.0      18.0  40.0  46.0  -6.0
# 9        Criciúma       38.0         9     11.0      18.0  42.0  61.0 -19.0
# 7     Atlético-GO       30.0         7      9.0      22.0  29.0  58.0 -29.0
# 8          Cuiabá       30.0         6     12.0      20.0  29.0  49.0 -20.0

# %% [markdown]
# **Exercício 2:** Média de vitórias.
#
# Calcule a média de vitórias de todos os times.

# %%
media = ordenado_final['Vitórias'].mean()
display(media)
# Out:
# 13.95

# %% [markdown]
# **Exercício 3:** Time com maior número de vitórias.
#
# Encontre o time que obteve o maior número de vitórias.

# %%
maior = ordenado_final.loc[ordenado_final['Vitórias'] ==  ordenado_final['Vitórias'].max()]
display(maior)
# Out:
#        Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG
# 0  Botafogo       79.0        23     10.0       5.0  59.0  29.0  30.0

# %% [markdown]
# **Exercício 4:** Análise dos times rebaixados.
#
# Se considerarmos que os 4 últimos colocados são rebaixados, crie um DataFrame apenas com esses times.
# Exiba esses times com todas as suas informações.

# %%
rebaixados = ordenado_final.tail(4)
dt_rebaixados = pd.DataFrame(rebaixados)
display(dt_rebaixados,)
# Out:
#             Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG
# 10  Athletico-PR       42.0        11      9.0      18.0  40.0  46.0  -6.0
# 9       Criciúma       38.0         9     11.0      18.0  42.0  61.0 -19.0
# 7    Atlético-GO       30.0         7      9.0      22.0  29.0  58.0 -29.0
# 8         Cuiabá       30.0         6     12.0      20.0  29.0  49.0 -20.0

# %% [markdown]
# **Exercício 5:** Time com pior saldo de gols.
#
# Encontre o time com o pior saldo de gols e exiba suas informações.

# %%
pior_saldo = ordenado_final.loc[ordenado_final['SG'] ==  ordenado_final['SG'].min()]
display(pior_saldo)
# Out:
#           Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG
# 7  Atlético-GO       30.0         7      9.0      22.0  29.0  58.0 -29.0

# %% [markdown]
# **Exercício 6:** Análise de desempenho.
#
# Filtre os times que têm mais de 10 vitórias e menos de 15 derrotas. Exiba esses times com todas as suas informações.

# %%
analise = ordenado_final.loc[(ordenado_final['Vitórias'] > 10) & (ordenado_final['Derrotas'] < 15)]
display(analise)
# Out:
#              Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG
# 0        Botafogo       79.0        23     10.0       5.0  59.0  29.0  30.0
# 19      Palmeiras       73.0        22      7.0       9.0  60.0  33.0  27.0
# 1        Flamengo       70.0        20     10.0       8.0  61.0  42.0  19.0
# 18      Fortaleza       68.0        19     11.0       8.0  53.0  39.0  14.0
# 2   Internacional       65.0        18     11.0       9.0  53.0  36.0  17.0
# 17      São Paulo       59.0        17      8.0      13.0  53.0  43.0  10.0
# 3     Corinthians       56.0        15     11.0      12.0  54.0  45.0   9.0
# 15       Cruzeiro       52.0        14     10.0      14.0  43.0  41.0   2.0
# 13    Atlético-MG       47.0        11     14.0      13.0  47.0  54.0  -7.0

# %% [markdown]
# **Exercício 7:** Adicionando uma coluna de Situação.
#
# Crie uma coluna chamada "Situação" que contenha "Aprovado" para times com pontuação maior ou igual a 50 e "Rebaixado" para os times com pontuação menor que 50.

# %%
situacao = ordenado_final[['Time','Pontuação']].head(6)
ordenado_final.loc[ordenado_final.index[0:7], 'Situação'] = 'Libertadores'
ordenado_final.loc[ordenado_final.index[8:14], 'Situação'] = 'Sul-Americana'
ordenado_final.loc[ordenado_final.index[14:16], 'Situação'] = 'Nada'
ordenado_final.loc[ordenado_final.index[16:], 'Situação'] = 'Rebaixado'
ordenado_final.index = ordenado_final.index + 1
display(ordenado_final)
# Out:
#              Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG  \
# 1        Botafogo       79.0        23     10.0       5.0  59.0  29.0  30.0
# 2       Palmeiras       73.0        22      7.0       9.0  60.0  33.0  27.0
# 3        Flamengo       70.0        20     10.0       8.0  61.0  42.0  19.0
# 4       Fortaleza       68.0        19     11.0       8.0  53.0  39.0  14.0
# 5   Internacional       65.0        18     11.0       9.0  53.0  36.0  17.0
# 6       São Paulo       59.0        17      8.0      13.0  53.0  43.0  10.0
# 7     Corinthians       56.0        15     11.0      12.0  54.0  45.0   9.0
# 8           Bahia       53.0        15      8.0      15.0  49.0  49.0   0.0
# 9        Cruzeiro       52.0        14     10.0      14.0  43.0  41.0   2.0
# 10  Vasco da Gama       50.0        14      8.0      16.0  43.0  56.0 -13.0
# 11     EC Vitória       47.0        13      8.0      17.0  45.0  52.0  -7.0
# 12    Atlético-MG       47.0        11     14.0      13.0  47.0  54.0  -7.0
# 13     Fluminense       46.0        12     10.0      16.0  33.0  39.0  -6.0
# 14         Grêmio       45.0        12      9.0      17.0  44.0  50.0  -6.0
# 15      Juventude       45.0        11     12.0      15.0  48.0  59.0 -11.0
# 16     Bragantino       44.0        10     14.0      14.0  44.0  48.0  -4.0
# 17   Athletico-PR       42.0        11      9.0      18.0  40.0  46.0  -6.0
# 18       Criciúma       38.0         9     11.0      18.0  42.0  61.0 -19.0
# 19    Atlético-GO       30.0         7      9.0      22.0  29.0  58.0 -29.0
# 20         Cuiabá       30.0         6     12.0      20.0  29.0  49.0 -20.0
#
#          Situação
# 1    Libertadores
# 2    Libertadores
# 3    Libertadores
# 4    Libertadores
# 5    Libertadores
# 6    Libertadores
# 7    Libertadores
# 8    Libertadores
# 9   Sul-Americana
# 10  Sul-Americana
# 11  Sul-Americana
# 12  Sul-Americana
# 13  Sul-Americana
# 14  Sul-Americana
# 15           Nada
# 16           Nada
# 17      Rebaixado
# 18      Rebaixado
# 19      Rebaixado
# 20      Rebaixado

# %% [markdown]
# **Exercício 8:** Melhor desempenho em gols.
#
# Encontre o time com maior número de gols feitos (GM) e exiba as informações.

# %%
desemepenho = ordenado_final.loc[ordenado_final['GM'] == ordenado_final['GM'].max()]
display(desemepenho)
# Out:
#        Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG  \
# 3  Flamengo       70.0        20     10.0       8.0  61.0  42.0  19.0
#
#        Situação
# 3  Libertadores

# %% [markdown]
# **Exercício 9:** Comparação entre vitórias e empates.
#
# Encontre a diferença entre o número de vitórias e empates de cada time e crie uma nova coluna chamada "Diferença de Vitória-empate". Exiba o DataFrame com essa nova coluna.

# %%
diferenca = ordenado_final['Diferença Vitória/Empate'] = ordenado_final['Vitórias'] - ordenado_final['Empates']
display(ordenado_final)
# Out:
#              Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG  \
# 1        Botafogo       79.0        23     10.0       5.0  59.0  29.0  30.0
# 2       Palmeiras       73.0        22      7.0       9.0  60.0  33.0  27.0
# 3        Flamengo       70.0        20     10.0       8.0  61.0  42.0  19.0
# 4       Fortaleza       68.0        19     11.0       8.0  53.0  39.0  14.0
# 5   Internacional       65.0        18     11.0       9.0  53.0  36.0  17.0
# 6       São Paulo       59.0        17      8.0      13.0  53.0  43.0  10.0
# 7     Corinthians       56.0        15     11.0      12.0  54.0  45.0   9.0
# 8           Bahia       53.0        15      8.0      15.0  49.0  49.0   0.0
# 9        Cruzeiro       52.0        14     10.0      14.0  43.0  41.0   2.0
# 10  Vasco da Gama       50.0        14      8.0      16.0  43.0  56.0 -13.0
# 11     EC Vitória       47.0        13      8.0      17.0  45.0  52.0  -7.0
# 12    Atlético-MG       47.0        11     14.0      13.0  47.0  54.0  -7.0
# 13     Fluminense       46.0        12     10.0      16.0  33.0  39.0  -6.0
# 14         Grêmio       45.0        12      9.0      17.0  44.0  50.0  -6.0
# 15      Juventude       45.0        11     12.0      15.0  48.0  59.0 -11.0
# 16     Bragantino       44.0        10     14.0      14.0  44.0  48.0  -4.0
# 17   Athletico-PR       42.0        11      9.0      18.0  40.0  46.0  -6.0
# 18       Criciúma       38.0         9     11.0      18.0  42.0  61.0 -19.0
# 19    Atlético-GO       30.0         7      9.0      22.0  29.0  58.0 -29.0
# 20         Cuiabá       30.0         6     12.0      20.0  29.0  49.0 -20.0
#
#          Situação  Diferença Vitória/Empate
# 1    Libertadores                      13.0
# 2    Libertadores                      15.0
# 3    Libertadores                      10.0
# 4    Libertadores                       8.0
# 5    Libertadores                       7.0
# 6    Libertadores                       9.0
# 7    Libertadores                       4.0
# 8    Libertadores                       7.0
# 9   Sul-Americana                       4.0
# 10  Sul-Americana                       6.0
# 11  Sul-Americana                       5.0
# 12  Sul-Americana                      -3.0
# 13  Sul-Americana                       2.0
# 14  Sul-Americana                       3.0
# 15           Nada                      -1.0
# 16           Nada                      -4.0
# 17      Rebaixado                       2.0
# 18      Rebaixado                      -2.0
# 19      Rebaixado                      -2.0
# 20      Rebaixado                      -6.0

# %% [markdown]
# **Exercício 10:** Times que têm mais de 20 vitórias.
#
# Crie um DataFrame com os times que conseguiram mais de 20 vitórias. Exiba esse DataFrame.

# %%
mais_de_vinte = ordenado_final.loc[ordenado_final['Vitórias'] > 20]
pd.DataFrame(mais_de_vinte)
display(mais_de_vinte)
# Out:
#         Time  Pontuação  Vitórias  Empates  Derrotas    GM    GC    SG  \
# 1   Botafogo       79.0        23     10.0       5.0  59.0  29.0  30.0
# 2  Palmeiras       73.0        22      7.0       9.0  60.0  33.0  27.0
#
#        Situação
# 1  Libertadores
# 2  Libertadores
